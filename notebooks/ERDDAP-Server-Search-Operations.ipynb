# %% [markdown]
# ## Conecting to ERDDAP Server
#
# In this notebook we will explore the ERDDAP_Server functionality, and what type of information you can obtain from it.

# %%
from erddapClient import ERDDAP_Server

remoteS = ERDDAP_Server('https://coastwatch.pfeg.noaa.gov/erddap')

# Request the server version
remoteS.version
# Out:
# 'ERDDAP_version=2.12'

# %% [markdown]
# ## Doing search operations
#
# ERDDAP provides 3 ways to make search operations:
#
# - Using /search endpoint
# - Using /advancedSearc endpoint
# - A regular tabledap query to the allDatasets tabledap available in all ERDDAP Servers.
#
#
# ### Using /search endpoint
#
# The easyest way to start a search, just throw a keyword, and get results.  But also ERDDAP supports some filters in the search string. Consider the following example.

# %%
# Do a remote search, and use the filters to exclude 'Aqua' from the search
#
# For more available filters check remoteS.search?
# 

remoteS.search(searchFor='Gulf Mexico Daytime MODIS -Aqua')
# Out:
# <erddapClient.ERDDAP_SearchResults>
# Results:  10
# [
#   0 - <erddapClient.ERDDAP_Griddap> erdTGsstd1day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (1 Day Composite)"
#   1 - <erddapClient.ERDDAP_Griddap> erdTGsstd14day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (14 Day Composite)"
#   2 - <erddapClient.ERDDAP_Griddap> erdTGsstd3day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (3 Day Composite)"
#   3 - <erddapClient.ERDDAP_Griddap> erdTGsstd8day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (8 Day Composite)"
#   4 - <erddapClient.ERDDAP_Griddap> erdTGsstdmday , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (Monthly Composite)"
#   5 - <erddapClient.ERDDAP_Griddap> erdTGssta1day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (1 Day Composite)"
#   6 - <erddapClient.ERDDAP_Griddap> erdTGssta14day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (14 Day Composite)"
#   7 - <erddapClient.ERDDAP_Griddap> erdTGssta3day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (3 Day Composite)"
#   8 - <erddapClient.ERDDAP_Griddap> erdTGssta8day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (8 Day Composite)"
#   9 - <erddapClient.ERDDAP_Griddap> erdTGsstamday , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (Monthly Composite)"
# ]

# %% [markdown]
# ### Using /advancedSearch endpoint
#
# With the advancedSearch you still use the searchFor query, and optionally add filters to your search by the following atributes:
#
# protocol, cdm_data_type, institution, ioos_category, keywords, long_name, standard_name, variableName, latlon coverage, and time coverage.
#
# > Use remoteS.advancedSearch? to get more information on each of the above optional filters.

# %%
# 
remoteS.advancedSearch(searchFor='Mexico', standard_name='sea_surface_temperature')
# Out:
# <erddapClient.ERDDAP_SearchResults>
# Results:  40
# [
#   0 - <erddapClient.ERDDAP_Griddap> erdMGsstd1day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (1 Day Composite)"
#   1 - <erddapClient.ERDDAP_Griddap> erdMGsstd14day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2002-2012 (14 Day Composite)"
#   2 - <erddapClient.ERDDAP_Griddap> erdMGsstd3day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2002-2012 (3 Day Composite)"
#   3 - <erddapClient.ERDDAP_Griddap> erdMGsstd8day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2002-2012 (8 Day Composite)"
#   4 - <erddapClient.ERDDAP_Griddap> erdMGsstdmday , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2002-2012 (Monthly Composite)"
#   5 - <erddapClient.ERDDAP_Griddap> erdMGssta1day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2002-2012 (1 Day Composite)"
#   6 - <erddapClient.ERDDAP_Griddap> erdMGssta14day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2002-2012 (14 Day Composite)"
#   7 - <erddapClient.ERDDAP_Griddap> erdMGssta3day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2002-2012 (3 Day Composite)"
#   8 - <erddapClient.ERDDAP_Griddap> erdMGssta8day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2002-2012 (8 Day Composite)"
#   9 - <erddapClient.ERDDAP_Griddap> erdMGsstamday , "SST, Aqua MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2002-2012 (Monthly Composite)"
#   10 - <erddapClient.ERDDAP_Griddap> erdMGsstn1day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2002-2012 (1 Day Composite)"
#   11 - <erddapClient.ERDDAP_Griddap> erdMGsstn14day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2002-2012 (14 Day Composite)"
#   12 - <erddapClient.ERDDAP_Griddap> erdMGsstn3day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2002-2012 (3 Day Composite)"
#   13 - <erddapClient.ERDDAP_Griddap> erdMGsstn8day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2002-2012 (8 Day Composite)"
#   14 - <erddapClient.ERDDAP_Griddap> erdMGsstnmday , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2002-2012 (Monthly Composite)"
#   15 - <erddapClient.ERDDAP_Griddap> erdMGsst41day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2002-2012 (1 Day Composite)"
#   16 - <erddapClient.ERDDAP_Griddap> erdMGsst414day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2002-2012 (14 Day Composite)"
#   17 - <erddapClient.ERDDAP_Griddap> erdMGsst43day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2002-2012 (3 Day Composite)"
#   18 - <erddapClient.ERDDAP_Griddap> erdMGsst48day , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2002-2012 (8 Day Composite)"
#   19 - <erddapClient.ERDDAP_Griddap> erdMGsst4mday , "SST, Aqua MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2002-2012 (Monthly Composite)"
#   20 - <erddapClient.ERDDAP_Griddap> erdTGsstd1day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (1 Day Composite)"
#   21 - <erddapClient.ERDDAP_Griddap> erdTGsstd14day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (14 Day Composite)"
#   22 - <erddapClient.ERDDAP_Griddap> erdTGsstd3day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (3 Day Composite)"
#   23 - <erddapClient.ERDDAP_Griddap> erdTGsstd8day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (8 Day Composite)"
#   24 - <erddapClient.ERDDAP_Griddap> erdTGsstdmday , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime (11 microns), 2000-2012 (Monthly Composite)"
#   25 - <erddapClient.ERDDAP_Griddap> erdTGssta1day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (1 Day Composite)"
#   26 - <erddapClient.ERDDAP_Griddap> erdTGssta14day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (14 Day Composite)"
#   27 - <erddapClient.ERDDAP_Griddap> erdTGssta3day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (3 Day Composite)"
#   28 - <erddapClient.ERDDAP_Griddap> erdTGssta8day , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (8 Day Composite)"
#   29 - <erddapClient.ERDDAP_Griddap> erdTGsstamday , "SST, Terra MODIS, NPP, Gulf of Mexico, Daytime and Nighttime (11 microns), 2000-2012 (Monthly Composite)"
#   30 - <erddapClient.ERDDAP_Griddap> erdTGsstn1day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2000-2012 (1 Day Composite)"
#   31 - <erddapClient.ERDDAP_Griddap> erdTGsstn14day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2000-2012 (14 Day Composite)"
#   32 - <erddapClient.ERDDAP_Griddap> erdTGsstn3day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2000-2012 (3 Day Composite)"
#   33 - <erddapClient.ERDDAP_Griddap> erdTGsstn8day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2000-2012 (8 Day Composite)"
#   34 - <erddapClient.ERDDAP_Griddap> erdTGsstnmday , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (11 microns), 2000-2012 (Monthly Composite)"
#   35 - <erddapClient.ERDDAP_Griddap> erdTGsst41day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2000-2012 (1 Day Composite)"
#   36 - <erddapClient.ERDDAP_Griddap> erdTGsst414day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2000-2012 (14 Day Composite)"
#   37 - <erddapClient.ERDDAP_Griddap> erdTGsst43day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2000-2012 (3 Day Composite)"
#   38 - <erddapClient.ERDDAP_Griddap> erdTGsst48day , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2000-2012 (8 Day Composite)"
#   39 - <erddapClient.ERDDAP_Griddap> erdTGsst4mday , "SST, Terra MODIS, NPP, Gulf of Mexico, Nighttime (4 microns), 2000-2012 (Monthly Composite)"
# ]

# %% [markdown]
# ### Using allDatasets tabledap dataset
#
# ERDDAP has a special tabular dataset called [`allDataset`](https://coastwatch.pfeg.noaa.gov/erddap/rest.html#GriddapAndTabledap) which has data about all of the datasets currently available in the ERDDAP Server. There is a row for each dataset with different columns of information.
#
# Because this is a tabledap dataset, we can query the dataset using the ERDDAP methods to query a normal tabledap dataset.
#
# You can access this datasets, getting the `tabledapAllDatasets` property from the ERDDAP_Server object.

# %%
print(remoteS.tabledapAllDatasets)
# Out:
# <erddapClient.ERDDAP_Dataset>
# Title:       * The List of All Active Datasets in this ERDDAP *
# Server URL:  https://coastwatch.pfeg.noaa.gov/erddap
# Dataset ID:  allDatasets

# %%
allDatasets = remoteS.tabledapAllDatasets

# Show the available columns
allDatasets.variables.keys()
# Out:
# odict_keys(['datasetID', 'accessible', 'institution', 'dataStructure', 'cdm_data_type', 'class', 'title', 'minLongitude', 'maxLongitude', 'longitudeSpacing', 'minLatitude', 'maxLatitude', 'latitudeSpacing', 'minAltitude', 'maxAltitude', 'minTime', 'maxTime', 'timeSpacing', 'griddap', 'subset', 'tabledap', 'MakeAGraph', 'sos', 'wcs', 'wms', 'files', 'fgdc', 'iso19115', 'metadata', 'sourceUrl', 'infoUrl', 'rss', 'email', 'testOutOfDate', 'outOfDate', 'summary'])

# %%
# Get all the rows that match the following coverage
# 
allDatasets.clearQuery()  # Clear all the previous query constraints, variables 
                          # or serverside functions added 


allDatasets.addConstraint('cdm_data_type="Grid"') \
           .addConstraints(['minLatitude>=17','maxLatitude<=35','minLongitude>=-105','maxLongitude<=-72']) \
           .getDataFrame()
# Out:
#          datasetID accessible          institution dataStructure  \
# 0    erdMGchla1day     public  NOAA NMFS SWFSC ERD          grid
# 1   erdMGchla14day     public  NOAA NMFS SWFSC ERD          grid
# 2    erdMGchla3day     public  NOAA NMFS SWFSC ERD          grid
# 3    erdMGchla8day     public  NOAA NMFS SWFSC ERD          grid
# 4    erdMGchlamday     public  NOAA NMFS SWFSC ERD          grid
# ..             ...        ...                  ...           ...
# 69   erdTGsst43day     public  NOAA NMFS SWFSC ERD          grid
# 70   erdTGsst48day     public  NOAA NMFS SWFSC ERD          grid
# 71   erdTGsst4mday     public  NOAA NMFS SWFSC ERD          grid
# 72      usgsCeCrm3     public            NOAA NGDC          grid
# 73      usgsCeCrm4     public            NOAA NGDC          grid
#
#    cdm_data_type           class  \
# 0           Grid  EDDGridFromDap
# 1           Grid  EDDGridFromDap
# 2           Grid  EDDGridFromDap
# 3           Grid  EDDGridFromDap
# 4           Grid  EDDGridFromDap
# ..           ...             ...
# 69          Grid  EDDGridFromDap
# 70          Grid  EDDGridFromDap
# 71          Grid  EDDGridFromDap
# 72          Grid  EDDGridFromDap
# 73          Grid  EDDGridFromDap
#
#                                                 title  \
# 0   Chlorophyll-a, Aqua MODIS, NPP, Gulf of Mexico...
# 1   Chlorophyll-a, Aqua MODIS, NPP, Gulf of Mexico...
# 2   Chlorophyll-a, Aqua MODIS, NPP, Gulf of Mexico...
# 3   Chlorophyll-a, Aqua MODIS, NPP, Gulf of Mexico...
# 4   Chlorophyll-a, Aqua MODIS, NPP, Gulf of Mexico...
# ..                                                ...
# 69  SST, Terra MODIS, NPP, Gulf of Mexico, Nightti...
# 70  SST, Terra MODIS, NPP, Gulf of Mexico, Nightti...
# 71  SST, Terra MODIS, NPP, Gulf of Mexico, Nightti...
# 72  Topography, NOAA Coastal Relief Model, 3 arc s...
# 73  Topography, NOAA Coastal Relief Model, 3 arc s...
#
#     minLongitude (degrees_east)  maxLongitude (degrees_east)  \
# 0                        -100.0                        -75.0
# 1                        -100.0                        -75.0
# 2                        -100.0                        -75.0
# 3                        -100.0                        -75.0
# 4                        -100.0                        -75.0
# ..                          ...                          ...
# 69                       -100.0                        -75.0
# 70                       -100.0                        -75.0
# 71                       -100.0                        -75.0
# 72                        -87.0                        -78.0
# 73                        -94.0                        -87.0
#
#     longitudeSpacing (degrees_east)  ...  \
# 0                          0.012500  ...
# 1                          0.012500  ...
# 2                          0.012500  ...
# 3                          0.012500  ...
# 4                          0.012500  ...
# ..                              ...  ...
# 69                         0.012500  ...
# 70                         0.012500  ...
# 71                         0.012500  ...
# 72                         0.000833  ...
# 73                         0.000833  ...
#
#                                                  fgdc  \
# 0   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 1   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 2   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 3   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 4   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# ..                                                ...
# 69  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 70  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 71  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 72  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 73  https://coastwatch.pfeg.noaa.gov/erddap/metada...
#
#                                              iso19115  \
# 0   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 1   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 2   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 3   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 4   https://coastwatch.pfeg.noaa.gov/erddap/metada...
# ..                                                ...
# 69  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 70  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 71  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 72  https://coastwatch.pfeg.noaa.gov/erddap/metada...
# 73  https://coastwatch.pfeg.noaa.gov/erddap/metada...
#
#                                              metadata  \
# 0   https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 1   https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 2   https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 3   https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 4   https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# ..                                                ...
# 69  https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 70  https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 71  https://coastwatch.pfeg.noaa.gov/erddap/info/e...
# 72  https://coastwatch.pfeg.noaa.gov/erddap/info/u...
# 73  https://coastwatch.pfeg.noaa.gov/erddap/info/u...
#
#                                             sourceUrl  \
# 0   https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 1   https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 2   https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 3   https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 4   https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# ..                                                ...
# 69  https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 70  https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 71  https://oceanwatch.pfeg.noaa.gov/thredds/dodsC...
# 72  https://geoport.whoi.edu/thredds/dodsC/bathy/c...
# 73  https://geoport.whoi.edu/thredds/dodsC/bathy/c...
#
#                                               infoUrl  \
# 0   https://coastwatch.pfeg.noaa.gov/infog/MG_chla...
# 1   https://coastwatch.pfeg.noaa.gov/infog/MG_chla...
# 2   https://coastwatch.pfeg.noaa.gov/infog/MG_chla...
# 3   https://coastwatch.pfeg.noaa.gov/infog/MG_chla...
# 4   https://coastwatch.pfeg.noaa.gov/infog/MG_chla...
# ..                                                ...
# 69  https://coastwatch.pfeg.noaa.gov/infog/TG_sst4...
# 70  https://coastwatch.pfeg.noaa.gov/infog/TG_sst4...
# 71  https://coastwatch.pfeg.noaa.gov/infog/TG_sst4...
# 72  https://www.ngdc.noaa.gov/mgg/coastal/coastal....
# 73  https://www.ngdc.noaa.gov/mgg/coastal/coastal....
#
#                                                   rss  \
# 0   http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 1   http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 2   http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 3   http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 4   http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# ..                                                ...
# 69  http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 70  http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 71  http://coastwatch.pfeg.noaa.gov/erddap/rss/erd...
# 72  http://coastwatch.pfeg.noaa.gov/erddap/rss/usg...
# 73  http://coastwatch.pfeg.noaa.gov/erddap/rss/usg...
#
#                                                 email  testOutOfDate  \
# 0   https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 1   https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 2   https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 3   https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 4   https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# ..                                                ...            ...
# 69  https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 70  https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 71  https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 72  https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
# 73  https://coastwatch.pfeg.noaa.gov/erddap/subscr...            NaN
#
#    outOfDate                                            summary
# 0        NaN  NOAA CoastWatch distributes chlorophyll-a conc...
# 1        NaN  NOAA CoastWatch distributes chlorophyll-a conc...
# 2        NaN  NOAA CoastWatch distributes chlorophyll-a conc...
# 3        NaN  NOAA CoastWatch distributes chlorophyll-a conc...
# 4        NaN  NOAA CoastWatch distributes chlorophyll-a conc...
# ..       ...                                                ...
# 69       NaN  NOAA CoastWatch provides SST data from NASA's ...
# 70       NaN  NOAA CoastWatch provides SST data from NASA's ...
# 71       NaN  NOAA CoastWatch provides SST data from NASA's ...
# 72       NaN  This Coastal Relief Gridded database provides ...
# 73       NaN  This Coastal Relief Gridded database provides ...
#
# [74 rows x 36 columns]
